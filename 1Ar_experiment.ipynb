# %% [markdown]
# <span style="color:#87cefa; font-size:200%">Plots for Summery 2/4 2022</span>

# %%
from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.colors as colors
from scipy.special import rel_entr
import pickle
from mpl_toolkits.mplot3d import axes3d
from scipy.ndimage.filters import gaussian_filter

import matplotlib.patches as patches
import J_sat
#print("1")
import Mesh_data
#print("2")
import Mesh_data_server
import seaborn
#print("3")
import fort44_reader_server as fort
#print("4")
import Mesh_data_integrated
import b2fplasmf

al_new_g_sep_out_target_dist = Mesh_data_integrated.grid_data("./b2fgmtry_ng")[1] 
al_new_g_sep_in_target_dist = Mesh_data_integrated.grid_data("./b2fgmtry_ng")[0] 

# I know it looks suspicious, but that co~~ is dedicate to new g
al_newg_newmesh_facing = np.load("./gs_new_g_SAS.npy")


#reload(Mesh_data_integrated)
reload(fort)
reload(b2fplasmf)

eV = 1.60218e-19
import cmasher as cmr

Vesl = np.load('./KSTAR_vessel.npy')
# Out:
# /tmp/ipykernel_61459/1587455251.py:9: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
file_location = "/home/chanyeong/solps-iter/runs/Ar_3e19_31642_014500/4MW_31642_14500/"
n=28
facing_data= Mesh_data_integrated.facing_data("%s/b2fgmtry" %file_location)
fna = b2fplasmf.data("%s/b2fplasmf" %file_location,"fna", n)
bb = b2fplasmf.data("%s/b2fplasmf" %file_location,"bb", n)
qc = b2fplasmf.data("%s/b2fplasmf" %file_location,"qc", n)

geo_eff = (bb[3,1:,96]/bb[0,1:,96])/qc[1:,96]

# %%
J1 = np.zeros([n, 2, 38, 98])
J = np.zeros([n, 2, 38, 98])
np.shape(J1)
# Out:
# (28, 2, 38, 98)

# %%
e = 1.60217663*(10**(-19))
charge = []
charge.append(0)
charge.append(e*1)
charge.append(0)
charge.append(e*1)
charge.append(e*2)
charge.append(e*3)
charge.append(e*4)
charge.append(e*5)
charge.append(e*6)
charge.append(0)
charge.append(e*1)
charge.append(e*2)
charge.append(e*3)
charge.append(e*4)
charge.append(e*5)
charge.append(e*6)
charge.append(e*7)
charge.append(e*8)
charge.append(e*9)
charge.append(e*10)
charge.append(e*12)
charge.append(e*12)
charge.append(e*13)
charge.append(e*14)
charge.append(e*15)
charge.append(e*16)
charge.append(e*17)
charge.append(e*18)

# %%
reload(J_sat)
# Out:
# <module 'J_sat' from '/home/chanyeong/solps-iter/SOLPS-ITER_analysis/J_sat.py'>

# %%
a= J_sat.flux("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/",28)
plt.plot(data_out_dist[:37],a)

# %%
geo_31642_x = Mesh_data_integrated.mesh_data("./../runs/Ar_3e19_31642_014500/3MW_Ar_31642_14500/b2fgmtry")[0]
geo_31642_y = Mesh_data_integrated.mesh_data("./../runs/Ar_3e19_31642_014500/3MW_Ar_31642_14500/b2fgmtry")[1]

# %% [markdown]
# ## Choose  datas

# %%
dir_Data_1 = "/home/chanyeong/solps-iter/runs/Con_Ne_e19_Heating/H_32MW_Con/"

dir_Data_2 = "/home/chanyeong/solps-iter/runs/Con_Ne_e19_Heating/32MW_Con"



Ar_4MW_Ne_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_3e19_31642_014500/4MW_31642_14500/b2fplasmf","te",20)
Ar_3MW_Ne_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_3e19_31642_014500/3MW_Ar_31642_14500/b2fplasmf","te",20)

#L_32MW_Ne_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_e19_Heating/32MW_Con/b2fplasmf" ,"te",20)

#H_32MW_0_fht = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_3e19_31642_014500/4MW_31642_14500/b2fplasmf","fht",20)
#L_32MW_0_fht = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/32MW_Con/b2fplasmf" ,"fht",20)

#H_32MW_0_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/H_32MW_Con/b2fplasmf","te",20)
#L_32MW_0_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/32MW_Con/b2fplasmf" ,"te",20)

#H_8MW_Ne_fht = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_e19_Heating/H_8MW_Con/b2fplasmf","fht",20)
#L_8MW_Ne_fht = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_e19_Heating/8MW_Con/b2fplasmf" ,"fht",20)

#H_8MW_Ne_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/H_8MW_Con/b2fplasmf","te",20)
#L_8MW_Ne_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/8MW_Con/b2fplasmf" ,"te",20)

#H_8MW_0_fht = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/H_8MW_Con/b2fplasmf","fht",20)
#L_8MW_0_fht = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/8MW_Con/b2fplasmf" ,"fht",20)

#H_8MW_0_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/H_8MW_Con/b2fplasmf","te",20)
#L_8MW_0_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Con_Ne_0_Heating/8MW_Con/b2fplasmf" ,"te",20)

# %%
new_3MW_Ne_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/b2fplasmf","te",28)

# %%
new_3MW_Ne_ne = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/b2fplasmf","ne",28)

# %%
new_3MW_Ne_na = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/b2fplasmf","na",28)

# %%
Ar5e18_3MW_te = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_5e18wq_D2_e21_14500/3MW/b2fplasmf","te",28)
Ar5e18_3MW_ne = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_5e18wq_D2_e21_14500/3MW/b2fplasmf","ne",28)
Ar5e18_3MW_na = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_5e18wq_D2_e21_14500/3MW/b2fplasmf","na",28)

# %%
plt.plot(new_3MW_Ne_te[:,53]/eV)
plt.plot(Ar5e18_3MW_te[:,53]/eV)

# %%
plt.plot(100*np.sum(new_3MW_Ne_na[7:,:,53],axis=0)/np.sum(new_3MW_Ne_na[:,:,53],axis=0))
plt.plot(100*np.sum(Ar5e18_3MW_na[7:,:,53],axis=0)/np.sum(Ar5e18_3MW_na[:,:,53],axis=0))

# %%
np.shape(new_3MW_Ne_na)
# Out:
# (28, 38, 98)

# %%
plt.plot(Ar_3MW_Ne_te[:,53]/eV)

# %%
plt.figure(figsize=(8, 8))


plt.axes().set_aspect('equal')

plt.title(r"$N_{total}/N_{Ar}$(%)")
#plt.xlim(1.0,2.5)
#plt.ylim(-1.5,1.5)

#plt.xlim(1.2,1.6)
#plt.ylim(-1.4,-0.6)
#dataiwant_conv = dataiwant_conv.sum(axis=0)
#fort_rad =  np.abs(fort.eir_spec("./data_Heating_Geo","SAS_8MW_noNe"))
#fort_rad_total = np.sum(fort_rad[0],axis = 0) + fort_rad[1] + fort_rad[2]
#total_rad = np.sum(rqrad, axis=0)
#real_total_rad= np.abs(fort_rad_total+total_rad)
z=100*np.sum(new_3MW_Ne_na[7:,:,:],axis=0)/np.sum(new_3MW_Ne_na[:,:,:],axis=0)
plt.pcolormesh(geo_31642_x, geo_31642_y,z)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]
plt.plot(Vesl[0], Vesl[1])
plt.colorbar()

plt.show()
# Out:
# /tmp/ipykernel_61459/1697463709.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(geo_31642_x, geo_31642_y,z)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]

# %%
plt.figure(figsize=(8, 8))


plt.axes().set_aspect('equal')

plt.title(r"$N_{total}/N_{Ar}$(%)")
#plt.xlim(1.0,2.5)
#plt.ylim(-1.5,1.5)

#plt.xlim(1.2,1.6)
#plt.ylim(-1.4,-0.6)
#dataiwant_conv = dataiwant_conv.sum(axis=0)
#fort_rad =  np.abs(fort.eir_spec("./data_Heating_Geo","SAS_8MW_noNe"))
#fort_rad_total = np.sum(fort_rad[0],axis = 0) + fort_rad[1] + fort_rad[2]
#total_rad = np.sum(rqrad, axis=0)
#real_total_rad= np.abs(fort_rad_total+total_rad)
z=100*np.sum(Ar5e18_3MW_na[7:,:,:],axis=0)/np.sum(Ar5e18_3MW_na[:,:,:],axis=0)
plt.pcolormesh(geo_31642_x, geo_31642_y,z)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]
plt.plot(Vesl[0], Vesl[1])
plt.colorbar()

plt.show()
# Out:
# /tmp/ipykernel_61459/208711761.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(geo_31642_x, geo_31642_y,z)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]

# %%
plt.figure(figsize=(8, 8))


plt.axes().set_aspect('equal')

plt.title(r"$N_{total}/N_{Ar}$(%)")
#plt.xlim(1.0,2.5)
#plt.ylim(-1.5,1.5)

#plt.xlim(1.2,1.6)
#plt.ylim(-1.4,-0.6)
#dataiwant_conv = dataiwant_conv.sum(axis=0)
#fort_rad =  np.abs(fort.eir_spec("./data_Heating_Geo","SAS_8MW_noNe"))
#fort_rad_total = np.sum(fort_rad[0],axis = 0) + fort_rad[1] + fort_rad[2]
#total_rad = np.sum(rqrad, axis=0)
#real_total_rad= np.abs(fort_rad_total+total_rad)
z=100*np.sum(new_3MW_Ne_na[7:,:,:],axis=0)
plt.pcolormesh(geo_31642_x, geo_31642_y,z)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]
plt.plot(Vesl[0], Vesl[1])
plt.colorbar()

plt.show()
# Out:
# /tmp/ipykernel_61459/329115169.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(geo_31642_x, geo_31642_y,z)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]

# %%
rqrad_3MW = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/b2fplasmf","rqrad", 28)

eir_3MW = fort.eir_spec("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/")
z=np.sum(rqrad_3MW,axis=0)+np.sum(eir_3MW[0],axis=0)

# %%
vol_3MW = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_1e19_D2_e21_14500/3MW/b2fplasmf","vol", 28)

# %%
cmap = cmr.cosmic
fig=plt.figure(figsize=(12, 12))

fig.patch.set_facecolor('xkcd:white')

plt.axes().set_aspect('equal')

plt.title("Radiation(W,3MW case)", fontsize=15)
z=(np.sum(rqrad_3MW,axis=0)+np.sum(eir_3MW[0],axis=0))/(vol_3MW*1000000)
#plt.xlim(1.2,1.6)
#plt.ylim(-1.4,-0.6)
plt.pcolormesh(geo_31642_x, geo_31642_y,z, norm=colors.SymLogNorm(linthresh=0.001, linscale=0.03,vmin=0, vmax=np.max(z)),cmap=cmap)
plt.colorbar()

#plt.contour(Ar_31642_14500ms_x, Ar_31642_14500ms_y, z, 1, colors='k')


plt.show()
# Out:
# /tmp/ipykernel_61459/4294302065.py:12: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(geo_31642_x, geo_31642_y,z, norm=colors.SymLogNorm(linthresh=0.001, linscale=0.03,vmin=0, vmax=np.max(z)),cmap=cmap)

# %%
rqrad_Ar_5e18_3MW = b2fplasmf.data("/home/chanyeong/solps-iter/runs/Ar_5e18wq_D2_e21_14500/3MW/b2fplasmf","rqrad", 28)

eir_Ar_5e18_3MW = fort.eir_spec("/home/chanyeong/solps-iter/runs/Ar_5e18wq_D2_e21_14500/3MW/")

# %%
cmap = cmr.cosmic
fig=plt.figure(figsize=(12, 12))

fig.patch.set_facecolor('xkcd:white')

plt.axes().set_aspect('equal')

plt.title(r"Radiation($W/m^3$,3MW case)", fontsize=15)
z1=(np.sum(rqrad_Ar_5e18_3MW,axis=0)+np.sum(eir_Ar_5e18_3MW[0],axis=0))/(vol_3MW*1000000)
#plt.xlim(1.2,1.6)
#plt.ylim(-1.4,-0.6)
plt.pcolormesh(geo_31642_x, geo_31642_y,z1, norm=colors.SymLogNorm(linthresh=0.001, linscale=0.03,vmin=0, vmax=np.max(z1)),cmap=cmap)
plt.colorbar()

#plt.contour(Ar_31642_14500ms_x, Ar_31642_14500ms_y, z, 1, colors='k')


plt.show()
# Out:
# /tmp/ipykernel_61459/4240345234.py:12: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(geo_31642_x, geo_31642_y,z1, norm=colors.SymLogNorm(linthresh=0.001, linscale=0.03,vmin=0, vmax=np.max(z1)),cmap=cmap)

# %%
plt.figure(figsize=(8, 8))


plt.axes().set_aspect('equal')

plt.title(r"$T_e$(eV)")
#plt.xlim(1.2,1.6)
#plt.ylim(-1.4,-0.6)
#dataiwant_conv = dataiwant_conv.sum(axis=0)
#fort_rad =  np.abs(fort.eir_spec("./data_Heating_Geo","SAS_8MW_noNe"))
#fort_rad_total = np.sum(fort_rad[0],axis = 0) + fort_rad[1] + fort_rad[2]
#total_rad = np.sum(rqrad, axis=0)
#real_total_rad= np.abs(fort_rad_total+total_rad)
plt.pcolormesh(geo_31642_x, geo_31642_y,new_3MW_Ne_te/eV)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]

plt.colorbar()

plt.show()
# Out:
# /tmp/ipykernel_61459/533531183.py:14: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(geo_31642_x, geo_31642_y,new_3MW_Ne_te/eV)#a=fhe_b2fstate_co_KDEMO_3e19Ne[0,:,:]-fhe_b2fstate_al_KDEMO_3e19Ne[0,:,:]

# %% [markdown]
# ## Outer Traget Heat Flux data
