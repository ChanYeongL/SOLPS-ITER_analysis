# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys

# %%
trial ="sudo scp chanyeong@143.248.99.71:/home/chanyeong/solps-iter/runs/conventionalgeo_no_neon/KDEMO_Heating/b2fplasmf b2fplasmf_tiral"
os.system(trial)
# Out:
# sudo: a terminal is required to read the password; either use the -S option to read from standard input or configure an askpass helper
# sudo: a password is required
# 256

# %%
pt = 3
x= np.linspace(0, pt, 100)
y1 = np.exp(x)
y2 = np.exp(pt-x)
plt.plot(x,y1, label ="Supply")
plt.plot(x,y2, label = "Demand")
plt.xlabel("Num")
plt.ylabel("Price")
plt.title("Supply and demand")
plt.legend()
plt.savefig("./수요공급곡선.png")

# %%
a = np.load("rqrad_b2fplasmf_al_KSTAR_3e16Ne.npy")
b = np.load("rqrad_b2fplasmf_al_ITER_3e16Ne.npy")
c = np.load("rqrad_b2fplasmf_al_KDEMO_3e16Ne.npy")

# %%
print(a-b)
# Out:
# [[[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  2.67770053e-13  2.69497500e-12 ...  1.04523907e-11
#     2.87525378e-13  0.00000000e+00]
#   [ 0.00000000e+00  5.89186578e-13  4.49044913e-12 ...  1.40219008e-11
#     3.07991312e-13  0.00000000e+00]
#   ...
#   [ 0.00000000e+00 -5.26113446e-08 -5.71799592e-08 ... -4.09481976e-07
#    -1.02541050e-07  0.00000000e+00]
#   [ 0.00000000e+00 -1.10057284e-08 -1.62923334e-08 ... -1.33415719e-07
#    -2.50022378e-08  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]]
#
#  [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
# ...

# %%
plt.plot(x,y1)
plt.plot(x,y2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.special import rel_entr
import pickle





puff = "3e16Ne"


fname_list = list()
fname_list.append("b2fstate_al_KSTAR_%s" %puff)
fname_list.append("b2fstate_al_ITER_%s" %puff)
fname_list.append("b2fstate_al_KDEMO_%s" %puff)
#fname_list.append("b2fstate_al_3e7P_%s" %puff)
fname_list.append("b2fstate_co_KSTAR_%s" %puff)
fname_list.append("b2fstate_co_ITER_%s" %puff)
fname_list.append("b2fstate_co_KDEMO_%s" %puff)

densi_list = list()
densi_list.append("na")
densi_list.append("ne")

flux_list = list()
flux_list.append("fhe")
flux_list.append("fhi")

# %%
a = input("Choose workstation(e.g ws4)", )
print(a)
# Out:
# Choose workstation(e.g ws4) ws4
# ws4

# %%
lam = 10^(-6)
nu = c/lam
c = 2.988*10**6
h = 6.626*10**(-34)
k = 1.381*10**(-23)

def B1(Te):
    re = (2*h*(nu^(3))/c^2)*(1/((Exp^(h*nu/(k*Te)))-1))
    return re
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/chanyeonglee/LAB_local/data_postprocessing/codes_for_analysis/SOLPS-ITER_analysis/Untitled.ipynb 셀 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/chanyeonglee/LAB_local/data_postprocessing/codes_for_analysis/SOLPS-ITER_analysis/Untitled.ipynb#ch0000011?line=0'>1</a> lam = 10^(-6)
# ----> <a href='vscode-notebook-cell:/Users/chanyeonglee/LAB_local/data_postprocessing/codes_for_analysis/SOLPS-ITER_analysis/Untitled.ipynb#ch0000011?line=1'>2</a> nu = c/lam
#       <a href='vscode-notebook-cell:/Users/chanyeonglee/LAB_local/data_postprocessing/codes_for_analysis/SOLPS-ITER_analysis/Untitled.ipynb#ch0000011?line=2'>3</a> c = 2.988*10**6
# ...
