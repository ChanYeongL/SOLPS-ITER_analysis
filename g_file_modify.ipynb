# %%
text_file_path = './g024848.004000.x4_3times.equ'
new_text_content = ''

with open(text_file_path,'r') as f:
    #lines = f.readlines()
    lines = f.read().splitlines()
    for i, l in enumerate(lines):
        if 16<i<69 or 70<i<124:
            dum = l.split()
            dum_storage = []
            dum_len = len(dum)
            for j in range(dum_len):
                dum_in = float(dum[j])*3
                dum_in = format(dum_in,'1E')
                dum_storage.append(dum_in)
            #print(dum_storage)
            new_dum = '    '.join(str(e) for e in dum_storage)
            #print('   '.join(str(e) for e in dum_storage))
            
            new_string = new_dum
        else:
            #new_string = l.strip()
            new_string = l
            print(l)
            print(l.strip())
            
        if new_string:
            new_text_content += new_string + '\n' 
        else:
            new_text_content +=  '\n' 
   
#with open(text_file_path,'w') as f:
#    f.write(new_text_content)

with open(text_file_path,'w') as f:
    f.write(new_text_content)
# Out:
#     jm   :=  no. of grid points in radial direction;
# jm   :=  no. of grid points in radial direction;
#     km   :=  no. of grid points in vertical direction;
# km   :=  no. of grid points in vertical direction;
#     r    :=  radial   coordinates of grid points  [m];
# r    :=  radial   coordinates of grid points  [m];
#     z    :=  vertical coordinates of grid points  [m];
# z    :=  vertical coordinates of grid points  [m];
#     psi  :=  flux per radian at grid points      [Wb/rad];
# psi  :=  flux per radian at grid points      [Wb/rad];
#     psib :=  psi at plasma boundary              [Wb/rad];
# psib :=  psi at plasma boundary              [Wb/rad];
#     btf  :=  toroidal magnetic field                  [T];
# btf  :=  toroidal magnetic field                  [T];
#     rtf  :=  major radius at which btf is specified   [m];
# rtf  :=  major radius at which btf is specified   [m];
#
#
#
#
#     jm    =          257 ;
# jm    =          257 ;
#     km    =          257 ;
# ...

# %%
# Out:
# <class 'float'>
